# %% [markdown]
# # pre-requesties for Advanced RAG in LlamaIndex

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install nest_asyncio
# Out:
# ...
# <frozen posixpath>:82: RuntimeWarning: coroutine 'prepare_chat_params' was never awaited
# ...

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# %pip install -U llama-index

# %% [markdown]
# ## Extract

# %%
from llama_index.core import SimpleDirectoryReader

# file name as id
docs_nam_as_id = SimpleDirectoryReader(input_dir="/content/drive/MyDrive/RAG/DATA", filename_as_id=True).load_data()

# %%
len(docs_nam_as_id)  # one per page
# Out:
# 177

# %%
import pprint
pprint.pprint(docs_nam_as_id)
# Out:
# [Document(id_='/content/drive/MyDrive/RAG/DATA/Lexus-GX-2025-USA.pdf_part_0', embedding=None, metadata={'page_label': '1', 'file_name': 'Lexus-GX-2025-USA.pdf', 'file_path': '/content/drive/MyDrive/RAG/DATA/Lexus-GX-2025-USA.pdf', 'file_type': 'application/pdf', 'file_size': 7431299, 'creation_date': '2025-12-13', 'last_modified_date': '2025-12-13'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Job Number: LEXGX-P58105\n MY25 GX Brochure\n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
# ...

# %% [markdown]
# ## Transform

# %%
# hide some keys from llm

docs_nam_as_id[0].__dict__ # too much data about one doc
# Out:
# {'id_': '/content/drive/MyDrive/RAG/DATA/Lexus-GX-2025-USA.pdf_part_0',
#  'embedding': None,
#  'metadata': {'page_label': '1',
#   'file_name': 'Lexus-GX-2025-USA.pdf',
#   'file_path': '/content/drive/MyDrive/RAG/DATA/Lexus-GX-2025-USA.pdf',
#   'file_type': 'application/pdf',
#   'file_size': 7431299,
#   'creation_date': '2025-12-13',
#   'last_modified_date': '2025-12-13'},
#  'excluded_embed_metadata_keys': ['file_name',
#   'file_type',
#   'file_size',
#   'creation_date',
#   'last_modified_date',
#   'last_accessed_date'],
#  'excluded_llm_metadata_keys': ['file_name',
#   'file_type',
#   'file_size',
#   'creation_date',
#   'last_modified_date',
#   'last_accessed_date'],
#  'relationships': {},
#  'metadata_template': '{key}: {value}',
#  'metadata_separator': '\n',
#  'text_resource': MediaResource(embeddings=None, data=None, text='Job Number: LEXGX-P58105\n MY25 GX Brochure\n', path=None, url=None, mimetype=None),
#  'image_resource': None,
# ...

# %%
# %pip install llama-index-llms-google-genai llama-index
# Out:
# ...
# /usr/lib/python3.12/pathlib.py:404: RuntimeWarning: coroutine 'prepare_chat_params' was never awaited
#   parsed = [sys.intern(str(x)) for x in rel.split(sep) if x and x != '.']
# ...

# %% [markdown]
# ### You can enter your API key below or use another LLM

# %%
import os

os.environ["GOOGLE_API_KEY"] = "AIzaSyCgiEIWicINbxVh_Ssr6kCGtigFIfKVcAE"

# %%
from llama_index.llms.google_genai import GoogleGenAI

llm = GoogleGenAI(
    model="gemini-2.5-flash-lite",

)

resp = llm.complete("explain briefly about Lexus.")
print(resp)
# Out:
# Lexus is the **luxury vehicle division of Japanese automaker Toyota**.
#
# In essence, Lexus is known for:
#
# *   **Luxury and Comfort:** They focus on providing a premium driving experience with high-quality materials, refined interiors, and a smooth, quiet ride.
# *   **Reliability and Quality:** Building on Toyota's reputation, Lexus vehicles are generally considered very reliable and well-built.
# *   **Performance and Technology:** They offer a range of powerful engines and incorporate advanced technology and safety features.
# *   **Distinctive Styling:** Lexus vehicles have a recognizable, often bold, design language.
#
# Think of them as Toyota's upscale offering, competing with other luxury brands like BMW, Mercedes-Benz, and Audi.

# %%
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.ingestion import IngestionPipeline

text_splitter = SentenceSplitter(separator=" ", chunk_size=512, chunk_overlap=64)

pipeline = IngestionPipeline(transformations=[text_splitter])

nodes = pipeline.run(
    documents=docs_nam_as_id,
    in_place=True,
    show_progress=True,
)
# Out:
# Parsing nodes:   0%|          | 0/177 [00:00<?, ?it/s]

# %%
len(nodes)
# Out:
# 261

# %%
import pprint

pprint.pprint(nodes[0].__dict__)

#print(nodes[0].get_content(metadata_mode=MetadataMode))
# Out:
# {'node': TextNode(id_='48a0d7c5-a817-46e7-ab06-7e2bb9f9a2b6', embedding=None, metadata={'page_label': '22', 'file_name': 'Lexus-GX-2025-USA.pdf', 'file_path': '/content/drive/MyDrive/RAG/DATA/Lexus-GX-2025-USA.pdf', 'file_type': 'application/pdf', 'file_size': 7431299, 'creation_date': '2025-12-13', 'last_modified_date': '2025-12-13'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='/content/drive/MyDrive/RAG/DATA/Lexus-GX-2025-USA.pdf_part_21', node_type='4', metadata={'page_label': '22', 'file_name': 'Lexus-GX-2025-USA.pdf', 'file_path': '/content/drive/MyDrive/RAG/DATA/Lexus-GX-2025-USA.pdf', 'file_type': 'application/pdf', 'file_size': 7431299, 'creation_date': '2025-12-13', 'last_modified_date': '202
# ...

# %% [markdown]
# ## Index

# %%
# %pip install -Uq llama-index-embeddings-huggingface
# Out:
# ERROR:asyncio:Task was destroyed but it is pending!
# task: <Task pending name='Task-227' coro=<tqdm_asyncio.gather.<locals>.wrap_awaitable() running at /usr/local/lib/python3.12/dist-packages/tqdm/asyncio.py:76> wait_for=<Future pending cb=[Task.__wakeup()]> cb=[as_completed.<locals>._on_completion() at /usr/lib/python3.12/asyncio/tasks.py:618]>
# Exception ignored in: <coroutine object tqdm_asyncio.gather.<locals>.wrap_awaitable at 0x798bf3330040>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/asyncio.py", line 76, in wrap_awaitable
#     return i, await f
#               ^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/llama_index_instrumentation/dispatcher.py", line 398, in async_wrapper
#     active_span_id.reset(token)
# ValueError: <Token var=<ContextVar name='active_span_id' default=None at 0x798c4de970b0> at 0x798bf334efc0> was created in a different Context
# ERROR:asyncio:Task was destroyed but it is pending!
# ...

# %%
# Embeddings

from llama_index.embeddings.huggingface import HuggingFaceEmbedding

hf_embeddings = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")

test_embed = hf_embeddings.get_text_embedding("Hello my name is Hasan")
print(test_embed)
# Out:
# [-0.059892602264881134, 0.014096993021667004, 0.040849849581718445, -0.0032324395142495632, 0.009782499633729458, -0.05143158137798309, 0.07060986012220383, -0.011906435713171959, 0.033799853175878525, -0.06619729846715927, 0.008722920902073383, -0.047306571155786514, 0.013193128630518913, 0.014596838504076004, 0.04535922408103943, -0.012915311381220818, 0.03596051409840584, -0.007931421510875225, -0.055688563734292984, -0.03113379515707493, -0.038646768778562546, 0.006055803969502449, -0.015023084357380867, -0.05447569489479065, 0.01911366730928421, 0.03889726102352142, 0.03730160742998123, 0.0030626009684056044, -0.06199707090854645, -0.08665607869625092, 0.04605748876929283, -0.02347906120121479, 0.01647287979722023, 0.02626076154410839, -0.008325994946062565, -0.00012972277181688696, -0.0024627461098134518, 0.06483984738588333, -0.04108061641454697, 0.022390225902199745, 0.03902175650000572, -0.02746252715587616, 0.05089154839515686, -0.019071774557232857, 0.050718486309051514, -
# ...

# %%
# create index

from llama_index.core import VectorStoreIndex

index = VectorStoreIndex(nodes, embed_model=hf_embeddings)

# %% [markdown]
# ## Query

# %%
from llama_index.llms.google_genai import GoogleGenAI

llm_querying = GoogleGenAI(
    model="gemini-2.5-flash-lite"
)

query_engine = index.as_query_engine(llm=llm_querying)

response = query_engine.query(
    "what are different wheel sizes of lexus LX?"
)

print(response)
# Out:
# The Lexus LX offers 18-inch, 20-inch, and 22-inch wheel sizes.

# %%
from llama_index.llms.google_genai import GoogleGenAI

llm_querying = GoogleGenAI(
    model="gemini-2.5-flash-lite"
)

query_engine = index.as_query_engine(llm=llm_querying)

response = query_engine.query(
    "what are the differences between different 22 inch wheels in lexus lx?"
)

print(response)
# Out:
# The LX F SPORT Handling model comes with 22-inch forged wheels with a Dark Gray Metallic finish. The LX Ultra Luxury model features 22-inch forged alloy wheels with a Silver finish. The LX Luxury model is equipped with 22-inch forged alloy wheels with a machined finish.

# %%
response.__dict__
# Out:
# {'response': 'The LX F SPORT Handling model comes with 22-inch forged wheels with a Dark Gray Metallic finish. The LX Ultra Luxury model features 22-inch forged alloy wheels with a Silver finish. The LX Luxury model is equipped with 22-inch forged alloy wheels with a machined finish.',
# ...

# %% [markdown]
# ## Store

# %%
index.storage_context.persist(persist_dir="/content/drive/MyDrive/RAG/vectors")

# %%
from llama_index.core import StorageContext, load_index_from_storage

# rebuild storage context
storage_context = StorageContext.from_defaults(persist_dir="/content/drive/MyDrive/RAG/vectors")

# load index
index_from_storage = load_index_from_storage(storage_context, embed_model=hf_embeddings)

# %%
qa = index_from_storage.as_query_engine(llm=llm_querying)

# %%
response = qa.query("what are the differences between different 22 inch wheels in lexus lx?")
print(response)
# Out:
# The LX F SPORT Handling model comes with 22-inch forged wheels with a Dark Gray Metallic finish. The LX Ultra Luxury model features 22-inch forged alloy wheels with a Silver finish. The LX Luxury model is equipped with 22-inch forged alloy wheels with a machined finish.

# %% [markdown]
# # Using Vector Stores

# %%
# %pip install -Uq chromadb
# %pip install -Uq llama-index-vector-stores-chroma
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.7/21.7 MB 115.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 26.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 98.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 99.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.0/220.0 kB 21.5 MB/s eta 0:00:00
# ...

# %%
print(type(nodes))
print(len(nodes) if hasattr(nodes, "__len__") else "no len")
print(type(nodes[0]) if isinstance(nodes, list) and len(nodes) > 0 else "no first item")
# Out:
# <class 'list'>
# 261
# <class 'llama_index.core.schema.TextNode'>

# %%
import chromadb
from llama_index.core import VectorStoreIndex
from llama_index.vector_stores.chroma import ChromaVectorStore
from llama_index.core import StorageContext

# initialize client, setting path to save data
db = chromadb.PersistentClient(path="/content/drive/MyDrive/RAG/chroma_db")

# create collection
chroma_collection = db.get_or_create_collection("lexus_brochures")

# assign chroma as the vector_store to the context
vector_store = ChromaVectorStore(chroma_collection=chroma_collection)
storage_context = StorageContext.from_defaults(vector_store=vector_store)

# create your index
index = VectorStoreIndex(
    nodes, storage_context=storage_context, embed_model=hf_embeddings
)



# create a query engine and query
query_engine = index.as_query_engine(llm=llm_querying)

# %%
response = query_engine.query("what are the differences between different 22 inch wheels in lexus lx?")
print(response)
# Out:
# The LX F SPORT Handling model comes with 22-inch forged wheels with a Dark Gray Metallic finish. The LX Ultra Luxury model features 22-inch forged alloy wheels with a Silver finish. The LX Luxury model is equipped with 22-inch forged alloy wheels with a machined finish.
